# %%
import swift_app as swift
import pandas as pd
import glob

# %%
result = swift.run(
    basin="Krishna",
    datasets=["solar",'discharge']
)

files = glob.glob(f"{result['output_dir']}/discharge/*.csv")

df = pd.read_csv(files[0])
df.head()
